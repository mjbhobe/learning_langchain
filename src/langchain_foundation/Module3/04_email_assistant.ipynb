# %% [markdown]
# # 04 Email Assistant
#
# In this notebook, we'll pull together all concepts we learnt in this module and build an Email Agent, which will do the following:
# * **Authenticate the user** - only then are they allowed into the email box!
# * **Read email from inbox**
# * **Send email with human approval required**
# To make things simple, we won't read emails from an actual inbox, nor will we send email - these will be replaced with dummy functions.

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True
