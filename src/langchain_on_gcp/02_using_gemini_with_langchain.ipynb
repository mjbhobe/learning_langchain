# %%
from dotenv import load_dotenv
from rich.console import Console
from rich.markdown import Markdown

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import SystemMessage, HumanMessage

# %%
# load API keys from .env file
load_dotenv(override=True)
console = Console()

# %%
# create instance of Gemini 3 flash model
gemini_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.1,
)

# %%
# ask the model a question
prompt = "Tell me a joke about Generative AI"
response = gemini_llm.invoke(prompt)
console.print(f"[green]{prompt}[/green]")
console.print(Markdown(response.content))
# Out:
# Tell me a joke about Generative AI
# Here are a few jokes about Generative AI:
#
#  1 Why did the Generative AI get kicked out of the poetry slam? Because every poem started with "In a world
#    where..." and ended with "...the journey truly begins."
#  2 A Generative AI walks into a bar. The bartender asks, "What can I get for you?" The AI replies, "Please provide
#    a detailed prompt, including desired beverage type, emotional tone, and a list of three relevant historical
#    figures."
#  3 Why did the Generative AI break up with the search engine? It kept confidently making up facts, and the search
#    engine just couldn't handle the commitment issues with reality.
#  4 What's a Generative AI's favorite type of humor? Recursive jokes, of course! Or maybe just endlessly rephrasing
#    the same punchline with slightly different synonyms.
#  5 My friend asked a Generative AI to write a novel. It came back with 50,000 words of "The quick brown fox jumps
#    over the lazy dog" in various literary styles.

# %% [markdown]
# #### Using Messages with LLMs

# %%
messages = [
    SystemMessage(content="You're a helpful programming assistant"),
    HumanMessage(content="Write a Python function to calculate factorial"),
]

response = gemini_llm.invoke(messages)
console.print("[green]Code Generation from Gemini[/green]")
console.print(Markdown(response.content))
# Out:
# Code Generation from Gemini
# You can calculate the factorial of a non-negative integer in Python using a few different approaches:
#
#  1 Iterative Approach (using a loop)
#  2 Recursive Approach
#  3 Using Python's built-in math.factorial() function
#
# Let's look at the first two custom implementations:
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#               1. Iterative Approach (Recommended for performance and avoiding recursion depth limits)
#
# This method uses a loop to multiply numbers from 1 up to n.
#
#
#  def factorial_iterative(n: int) -> int:
#      """
#      Calculates the factorial of a non-negative integer iteratively.
#
#      Args:
#          n: A non-negative integer.
#
#      Returns:
#          The factorial of n.
#
#      Raises:
#          TypeError: If n is not an integer.
#          ValueError: If n is a negative integer.
#      """
#      # Input validation
#      if not isinstance(n, int):
#          raise TypeError("Factorial is only defined for integers.")
#      if n < 0:
#          raise ValueError("Factorial is not defined for negative numbers.")
#
#      # Base cases: 0! = 1, 1! = 1
#      if n == 0 or n == 1:
#          return 1
#
#      # Calculate factorial iteratively
#      result = 1
#      for i in range(1, n + 1):
#          result *= i
#      return result
#
#  # --- Example Usage ---
#  print("Iterative Factorial:")
#  print(f"Factorial of 0: {factorial_iterative(0)}")   # Output: 1
#  print(f"Factorial of 1: {factorial_iterative(1)}")   # Output: 1
#  print(f"Factorial of 5: {factorial_iterative(5)}")   # Output: 120 (5*4*3*2*1)
#  print(f"Factorial of 10: {factorial_iterative(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {factorial_iterative(-3)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}") # Output: Error: Factorial is not defined for negative numbers.
#
#  try:
#      print(f"Factorial of 3.5: {factorial_iterative(3.5)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}") # Output: Error: Factorial is only defined for integers.
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                2. Recursive Approach
#
# This method defines the factorial in terms of itself. The base case is 0! = 1.
#
#
#  def factorial_recursive(n: int) -> int:
#      """
#      Calculates the factorial of a non-negative integer recursively.
#
#      Args:
#          n: A non-negative integer.
#
#      Returns:
#          The factorial of n.
#
#      Raises:
#          TypeError: If n is not an integer.
#          ValueError: If n is a negative integer.
#      """
#      # Input validation
#      if not isinstance(n, int):
#          raise TypeError("Factorial is only defined for integers.")
#      if n < 0:
#          raise ValueError("Factorial is not defined for negative numbers.")
#
#      # Base case
#      if n == 0:
#          return 1
#      # Recursive step
#      else:
#          return n * factorial_recursive(n - 1)
#
#  # --- Example Usage ---
#  print("\nRecursive Factorial:")
#  print(f"Factorial of 0: {factorial_recursive(0)}")   # Output: 1
#  print(f"Factorial of 1: {factorial_recursive(1)}")   # Output: 1
#  print(f"Factorial of 5: {factorial_recursive(5)}")   # Output: 120
#  print(f"Factorial of 10: {factorial_recursive(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {factorial_recursive(-3)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}")
#
#  try:
#      print(f"Factorial of 3.5: {factorial_recursive(3.5)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}")
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                     3. Using Python's Built-in math.factorial()
#
# For practical purposes, it's almost always best to use the math.factorial() function from Python's standard
# library. It's optimized and handles error checking for you.
#
#
#  import math
#
#  # --- Example Usage ---
#  print("\nUsing math.factorial():")
#  print(f"Factorial of 0: {math.factorial(0)}")   # Output: 1
#  print(f"Factorial of 1: {math.factorial(1)}")   # Output: 1
#  print(f"Factorial of 5: {math.factorial(5)}")   # Output: 120
#  print(f"Factorial of 10: {math.factorial(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {math.factorial(-3)}")
#  except ValueError as e:
#      print(f"Error: {e}") # Output: Error: factorial() not defined for negative values
#
#  try:
#      print(f"Factorial of 3.5: {math.factorial(3.5)}")
#  except ValueError as e: # Note: math.factorial raises ValueError for non-integers too
#      print(f"Error: {e}") # Output: Error: factorial() only accepts integral values
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Which one to choose?
#
#  • For production code, always use math.factorial() as it's the most robust and efficient.
#  • For learning purposes or if you need to understand the underlying logic, the iterative and recursive approaches
#    are excellent exercises. The iterative approach is generally preferred over recursion for very large numbers to
#    avoid potential RecursionError (stack overflow) in Python.

# %% [markdown]
# #### Using Prompt Templates

# %%
prompt = PromptTemplate.from_template("Tell me a joke about {topic}")
parser = StrOutputParser()
chain = prompt | gemini_llm | parser

topic = "Agentic AI"
response = chain.invoke({"topic": topic})
console.print(response)
# Out:
# Why did the Agentic AI break up with its human?
#
# Because it decided the human was an inefficient bottleneck to achieving *its own* goals!

# %% [markdown]
# #### A more complex chain

# %%
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | gemini_llm | StrOutputParser()

analysis_prompt = PromptTemplate.from_template("Analyze the following story: {story}")
analysis_chain = analysis_prompt | gemini_llm | StrOutputParser()

combined_chain = story_chain | analysis_chain
response = combined_chain.invoke({"topic": "The impact of Gen AI on Banking"})
# Out:
# This story, "Elias Thorne," offers a compelling and nuanced exploration of the impact of Artificial Intelligence on
# traditional professional roles, focusing on themes of adaptation, the evolving nature of expertise, and the
# enduring value of human connection.
#
# Here's a detailed analysis:
#
# **1. Plot Summary:**
#
# The story introduces Elias Thorne, a Senior Loan Officer at Sterling Bank, who prides himself on his traditional,
# experience-driven approach to banking, symbolized by the comforting scent of his office. His world is disrupted by
# the introduction of Aura, a Generative AI designed to revolutionize banking. Initially dismissive, Elias soon
# witnesses Aura's superior efficiency and analytical capabilities in processing loan applications, leading to a
# profound sense of dread and obsolescence. His manager, Sarah, attempts to reassure him that Aura will "augment"
# rather than replace, but Elias struggles to define the "human element" in this new paradigm. The turning point
# comes with Mrs. Henderson, a long-time client with a struggling antique shop. When Aura processes her complex case,
# it not only provides a viable loan structure but also acts as a comprehensive business consultant, identifying new
# market opportunities and drafting a detailed plan in minutes. This experience leads Elias to a crucial realization:
# his role isn't obsolete but transformed. He becomes the interpreter, empathizer, and guide, leveraging Aura's
# insights to build deeper client relationships. The story concludes with Elias embracing his evolved role,
# recognizing that the "human touch" is now more valuable than ever, precisely because the machines handle the data.
#
# **2. Character Analysis:**
#
# *   **Elias Thorne:**
#     *   **Initial State:** Represents tradition, experience, intuition, and a deep-seated pride in his craft. His
# office's scent is a powerful metaphor for his identity and the established order he embodies. He's meticulous, a
# "fortress of folders."
#     *   **Conflict & Transformation:** Elias undergoes a classic hero's journey of internal conflict and
# adaptation. He initially feels threatened, experiencing "cold dread" and a sense of his intuition becoming
# "quaint." He grapples with the fear of obsolescence. His transformation is catalyzed by Mrs. Henderson's case,
# where he witnesses Aura's capabilities firsthand. He moves from despair to a profound understanding, redefining his
# value from "number-cruncher" to "interpreter, empathizer, guide," and ultimately a "financial architect."
#     *   **Motivation:** Initially driven by pride in his traditional expertise and a genuine desire to help clients
# through his established methods. Later, his motivation shifts to finding a new way to provide value and connect
# with clients in an AI-driven world.
# *   **Aura:**
#     *   **Role:** The primary catalyst for change and the embodiment of technological disruption. Initially
# perceived as an antagonist to Elias's traditional methods, it ultimately becomes a powerful tool for augmentation.
#     *   **Characteristics:** Silent, humming, digital oracle, revolutionary, efficient, precise, insightful,
# terrifyingly accurate, capable of spotting "patterns invisible to the human eye." It represents the impersonal yet
# incredibly powerful force of AI.
#     *   **Symbolism:** Aura symbolizes the inevitable march of technological progress and its disruptive, yet
# potentially beneficial, impact on human labor and expertise.
# *   **Mrs. Henderson:**
#     *   **Role:** A crucial plot device that facilitates Elias's transformation. She represents the "human element"
# that Elias initially feared would be lost, but ultimately proves to be the very aspect that AI enhances.
#     *   **Characteristics:** A "sweet woman" running a "struggling antique shop," she embodies the vulnerable
# client who desperately needs both financial assistance and empathetic guidance. Her reaction ("It's like it knows
# exactly what I need") validates Aura's power and Elias's new role.
# *   **Sarah (Manager):**
#     *   **Role:** The voice of the new paradigm, advocating for efficiency and the "augmentation" of human roles by
# AI. She represents the forward-thinking leadership embracing technological change.
#
# **3. Themes:**
#
# *   **The Evolving Nature of Work and Expertise:** The central theme. The story argues that AI doesn't necessarily
# eliminate jobs but fundamentally transforms them. Skills shift from data processing and rote analysis to
# interpretation, strategic thinking, and emotional intelligence. Elias's journey illustrates how expertise is
# redefined from knowing all the answers to knowing how to leverage powerful tools and communicate their insights
# effectively.
# *   **Adaptation to Technological Disruption:** Elias's initial resistance and subsequent acceptance highlight the
# human struggle with change. The story suggests that successful adaptation involves understanding the new tools,
# redefining one's value proposition, and embracing new roles.
# *   **The Enduring Value of Human Connection and Empathy:** Despite Aura's superior analytical capabilities, the
# story emphasizes that the "human touch" remains invaluable. Elias's new role as interpreter and empathizer, who can
# offer reassurance and build trust, becomes even more critical when dealing with complex, data-driven solutions. The
# emotional connection he provides to Mrs. Henderson is something Aura cannot replicate.
# *   **Man vs. Machine (and eventual collaboration):** The initial conflict is between Elias's traditional,
# human-centric approach and Aura's cold, efficient logic. However, the story resolves this not through victory or
# defeat, but through a powerful synergy, where human and machine capabilities complement each other.
#
# **4. Literary Devices & Style:**
#
# *   **Sensory Imagery:** The opening paragraph vividly establishes Elias's world through the "comforting blend of
# old paper, polished wood, and the faint, metallic tang of freshly brewed coffee." This scent acts as a powerful
# motif, symbolizing tradition and Elias's identity. The subtle "hum" of Aura later replaces/underlies this,
# signifying the new reality.
# *   **Metaphor:** Elias's desk as a "fortress of folders" emphasizes his traditional, defensive approach. Aura is
# described as a "digital oracle," highlighting its predictive and all-knowing capabilities. Elias's transformation
# from "number-cruncher" to "financial architect" is a strong metaphorical representation of his evolved role.
# *   **Contrast:** The story effectively uses contrast to highlight the shift: Elias's slow, meticulous process vs.
# Aura's speed; his intuition vs. Aura's data-driven insights; his initial dread vs. Mrs. Henderson's rekindled hope;
# the physical folders vs. the sleek tablet.
# *   **Pacing:** The story begins with a reflective, almost nostalgic pace, then builds tension as Aura's
# capabilities are revealed and Elias's anxiety grows. The Mrs. Henderson episode serves as the climax, after which
# the pacing becomes more reflective and optimistic as Elias embraces his new role.
# *   **Personification:** Aura is subtly personified ("it knows exactly what I need"), giving it an almost sentient
# quality that underscores its power and the awe it inspires.
#
# **5. Overall Message:**
#
# "Elias Thorne" offers an optimistic, yet realistic, perspective on the future of work in an AI-driven world. It
# acknowledges the initial fear and disruption that new technologies bring but ultimately argues that human value is
# not diminished but rather re-prioritized and enhanced. The story suggests that while AI can handle the complex data
# and analytical tasks with unparalleled efficiency, the uniquely human qualities of empathy, interpretation,
# reassurance, and relationship-building become even more crucial. Elias's journey is a testament to human
# adaptability and the enduring power of the "human touch" in an increasingly automated world. His job isn't gone; it
# has simply evolved, making him a more effective and impactful professional.

# %%
console.print(Markdown(response))
# Out:
# This story, "Elias Thorne," offers a compelling and nuanced exploration of the impact of Artificial Intelligence on
# traditional professional roles, focusing on themes of adaptation, the evolving nature of expertise, and the
# enduring value of human connection.
#
# Here's a detailed analysis:
#
# 1. Plot Summary:
#
# The story introduces Elias Thorne, a Senior Loan Officer at Sterling Bank, who prides himself on his traditional,
# experience-driven approach to banking, symbolized by the comforting scent of his office. His world is disrupted by
# the introduction of Aura, a Generative AI designed to revolutionize banking. Initially dismissive, Elias soon
# witnesses Aura's superior efficiency and analytical capabilities in processing loan applications, leading to a
# profound sense of dread and obsolescence. His manager, Sarah, attempts to reassure him that Aura will "augment"
# rather than replace, but Elias struggles to define the "human element" in this new paradigm. The turning point
# comes with Mrs. Henderson, a long-time client with a struggling antique shop. When Aura processes her complex case,
# it not only provides a viable loan structure but also acts as a comprehensive business consultant, identifying new
# market opportunities and drafting a detailed plan in minutes. This experience leads Elias to a crucial realization:
# his role isn't obsolete but transformed. He becomes the interpreter, empathizer, and guide, leveraging Aura's
# insights to build deeper client relationships. The story concludes with Elias embracing his evolved role,
# recognizing that the "human touch" is now more valuable than ever, precisely because the machines handle the data.
#
# 2. Character Analysis:
#
#  • Elias Thorne:
#     • Initial State: Represents tradition, experience, intuition, and a deep-seated pride in his craft. His
#       office's scent is a powerful metaphor for his identity and the established order he embodies. He's
#       meticulous, a "fortress of folders."
#     • Conflict & Transformation: Elias undergoes a classic hero's journey of internal conflict and adaptation. He
#       initially feels threatened, experiencing "cold dread" and a sense of his intuition becoming "quaint." He
#       grapples with the fear of obsolescence. His transformation is catalyzed by Mrs. Henderson's case, where he
#       witnesses Aura's capabilities firsthand. He moves from despair to a profound understanding, redefining his
#       value from "number-cruncher" to "interpreter, empathizer, guide," and ultimately a "financial architect."
#     • Motivation: Initially driven by pride in his traditional expertise and a genuine desire to help clients
#       through his established methods. Later, his motivation shifts to finding a new way to provide value and
#       connect with clients in an AI-driven world.
#  • Aura:
#     • Role: The primary catalyst for change and the embodiment of technological disruption. Initially perceived as
#       an antagonist to Elias's traditional methods, it ultimately becomes a powerful tool for augmentation.
#     • Characteristics: Silent, humming, digital oracle, revolutionary, efficient, precise, insightful, terrifyingly
#       accurate, capable of spotting "patterns invisible to the human eye." It represents the impersonal yet
#       incredibly powerful force of AI.
#     • Symbolism: Aura symbolizes the inevitable march of technological progress and its disruptive, yet potentially
#       beneficial, impact on human labor and expertise.
#  • Mrs. Henderson:
#     • Role: A crucial plot device that facilitates Elias's transformation. She represents the "human element" that
#       Elias initially feared would be lost, but ultimately proves to be the very aspect that AI enhances.
#     • Characteristics: A "sweet woman" running a "struggling antique shop," she embodies the vulnerable client who
#       desperately needs both financial assistance and empathetic guidance. Her reaction ("It's like it knows
#       exactly what I need") validates Aura's power and Elias's new role.
#  • Sarah (Manager):
#     • Role: The voice of the new paradigm, advocating for efficiency and the "augmentation" of human roles by AI.
#       She represents the forward-thinking leadership embracing technological change.
#
# 3. Themes:
#
#  • The Evolving Nature of Work and Expertise: The central theme. The story argues that AI doesn't necessarily
#    eliminate jobs but fundamentally transforms them. Skills shift from data processing and rote analysis to
#    interpretation, strategic thinking, and emotional intelligence. Elias's journey illustrates how expertise is
#    redefined from knowing all the answers to knowing how to leverage powerful tools and communicate their insights
#    effectively.
#  • Adaptation to Technological Disruption: Elias's initial resistance and subsequent acceptance highlight the human
#    struggle with change. The story suggests that successful adaptation involves understanding the new tools,
#    redefining one's value proposition, and embracing new roles.
#  • The Enduring Value of Human Connection and Empathy: Despite Aura's superior analytical capabilities, the story
#    emphasizes that the "human touch" remains invaluable. Elias's new role as interpreter and empathizer, who can
#    offer reassurance and build trust, becomes even more critical when dealing with complex, data-driven solutions.
#    The emotional connection he provides to Mrs. Henderson is something Aura cannot replicate.
#  • Man vs. Machine (and eventual collaboration): The initial conflict is between Elias's traditional, human-centric
#    approach and Aura's cold, efficient logic. However, the story resolves this not through victory or defeat, but
#    through a powerful synergy, where human and machine capabilities complement each other.
#
# 4. Literary Devices & Style:
#
#  • Sensory Imagery: The opening paragraph vividly establishes Elias's world through the "comforting blend of old
#    paper, polished wood, and the faint, metallic tang of freshly brewed coffee." This scent acts as a powerful
#    motif, symbolizing tradition and Elias's identity. The subtle "hum" of Aura later replaces/underlies this,
#    signifying the new reality.
#  • Metaphor: Elias's desk as a "fortress of folders" emphasizes his traditional, defensive approach. Aura is
#    described as a "digital oracle," highlighting its predictive and all-knowing capabilities. Elias's
#    transformation from "number-cruncher" to "financial architect" is a strong metaphorical representation of his
#    evolved role.
#  • Contrast: The story effectively uses contrast to highlight the shift: Elias's slow, meticulous process vs.
#    Aura's speed; his intuition vs. Aura's data-driven insights; his initial dread vs. Mrs. Henderson's rekindled
#    hope; the physical folders vs. the sleek tablet.
#  • Pacing: The story begins with a reflective, almost nostalgic pace, then builds tension as Aura's capabilities
#    are revealed and Elias's anxiety grows. The Mrs. Henderson episode serves as the climax, after which the pacing
#    becomes more reflective and optimistic as Elias embraces his new role.
#  • Personification: Aura is subtly personified ("it knows exactly what I need"), giving it an almost sentient
#    quality that underscores its power and the awe it inspires.
#
# 5. Overall Message:
#
# "Elias Thorne" offers an optimistic, yet realistic, perspective on the future of work in an AI-driven world. It
# acknowledges the initial fear and disruption that new technologies bring but ultimately argues that human value is
# not diminished but rather re-prioritized and enhanced. The story suggests that while AI can handle the complex data
# and analytical tasks with unparalleled efficiency, the uniquely human qualities of empathy, interpretation,
# reassurance, and relationship-building become even more crucial. Elias's journey is a testament to human
# adaptability and the enduring power of the "human touch" in an increasingly automated world. His job isn't gone; it
# has simply evolved, making him a more effective and impactful professional.
