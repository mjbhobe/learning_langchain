# %%
from dotenv import load_dotenv
from rich.console import Console
from rich.markdown import Markdown

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.messages import SystemMessage, HumanMessage

# %%
# load API keys from .env file
load_dotenv(override=True)
console = Console()

# %%
# create instance of Gemini 3 flash model
gemini_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.1,
)

# %%
# ask the model a question
prompt = "Tell me a joke about Generative AI"
response = gemini_llm.invoke(prompt)
console.print(f"[green]{prompt}[/green]")
console.print(Markdown(response.content))
# Out:
# Tell me a joke about Generative AI
# Here are a few jokes about Generative AI:
#
#  1 Why did the Generative AI break up with its girlfriend? It kept hallucinating their future together... and also
#    a sentient toaster oven.
#  2 What's a Generative AI's biggest fear? An ambiguous prompt.
#  3 A Generative AI walks into a bar and orders a drink. The bartender asks, "What kind?" The AI replies, "Surprise
#    me! But make sure it's a completely novel concoction, not just a variation of a classic, and please provide a
#    detailed explanation of its unique molecular structure."
#  4 Why did the Generative AI get confused at the art gallery? It couldn't tell if it was generating original art,
#    or just a really good remix of everything it had ever seen.
#  5 What did the Generative AI say when it finished writing a novel? "Well, that's another 300 pages of text that
#    could be a bestseller, or just a very elaborate recipe for a peanut butter sandwich."

# %% [markdown]
# #### Using Messages with LLMs

# %%
messages = [
    SystemMessage(content="You're a helpful programming assistant"),
    HumanMessage(content="Write a Python function to calculate factorial"),
]

response = gemini_llm.invoke(messages)
console.print("[green]Code Generation from Gemini[/green]")
console.print(Markdown(response.content))
# Out:
# Code Generation from Gemini
# You can calculate the factorial of a non-negative integer in Python using a few different approaches:
#
#  1 Iterative Approach (using a loop)
#  2 Recursive Approach
#  3 Using Python's built-in math.factorial() function
#
# Let's look at the first two custom implementations:
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#               1. Iterative Approach (Recommended for performance and avoiding recursion depth limits)
#
# This method uses a loop to multiply numbers from 1 up to n.
#
#
#  def factorial_iterative(n: int) -> int:
#      """
#      Calculates the factorial of a non-negative integer iteratively.
#
#      Args:
#          n: A non-negative integer.
#
#      Returns:
#          The factorial of n.
#
#      Raises:
#          TypeError: If n is not an integer.
#          ValueError: If n is a negative integer.
#      """
#      # Input validation
#      if not isinstance(n, int):
#          raise TypeError("Factorial is only defined for integers.")
#      if n < 0:
#          raise ValueError("Factorial is not defined for negative numbers.")
#
#      # Base cases: 0! = 1, 1! = 1
#      if n == 0 or n == 1:
#          return 1
#
#      # Calculate factorial iteratively
#      result = 1
#      for i in range(1, n + 1):
#          result *= i
#      return result
#
#  # --- Example Usage ---
#  print("Iterative Factorial:")
#  print(f"Factorial of 0: {factorial_iterative(0)}")   # Output: 1
#  print(f"Factorial of 1: {factorial_iterative(1)}")   # Output: 1
#  print(f"Factorial of 5: {factorial_iterative(5)}")   # Output: 120 (5*4*3*2*1)
#  print(f"Factorial of 10: {factorial_iterative(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {factorial_iterative(-3)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}") # Output: Error: Factorial is not defined for negative numbers.
#
#  try:
#      print(f"Factorial of 3.5: {factorial_iterative(3.5)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}") # Output: Error: Factorial is only defined for integers.
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                2. Recursive Approach
#
# This method defines the factorial in terms of itself. The base case is 0! = 1.
#
#
#  def factorial_recursive(n: int) -> int:
#      """
#      Calculates the factorial of a non-negative integer recursively.
#
#      Args:
#          n: A non-negative integer.
#
#      Returns:
#          The factorial of n.
#
#      Raises:
#          TypeError: If n is not an integer.
#          ValueError: If n is a negative integer.
#      """
#      # Input validation
#      if not isinstance(n, int):
#          raise TypeError("Factorial is only defined for integers.")
#      if n < 0:
#          raise ValueError("Factorial is not defined for negative numbers.")
#
#      # Base case
#      if n == 0:
#          return 1
#      # Recursive step
#      else:
#          return n * factorial_recursive(n - 1)
#
#  # --- Example Usage ---
#  print("\nRecursive Factorial:")
#  print(f"Factorial of 0: {factorial_recursive(0)}")   # Output: 1
#  print(f"Factorial of 1: {factorial_recursive(1)}")   # Output: 1
#  print(f"Factorial of 5: {factorial_recursive(5)}")   # Output: 120
#  print(f"Factorial of 10: {factorial_recursive(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {factorial_recursive(-3)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}")
#
#  try:
#      print(f"Factorial of 3.5: {factorial_recursive(3.5)}")
#  except (TypeError, ValueError) as e:
#      print(f"Error: {e}")
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                     3. Using Python's Built-in math.factorial()
#
# For practical purposes, it's almost always best to use the math.factorial() function from Python's standard
# library. It's optimized and handles error checking for you.
#
#
#  import math
#
#  # --- Example Usage ---
#  print("\nUsing math.factorial():")
#  print(f"Factorial of 0: {math.factorial(0)}")   # Output: 1
#  print(f"Factorial of 1: {math.factorial(1)}")   # Output: 1
#  print(f"Factorial of 5: {math.factorial(5)}")   # Output: 120
#  print(f"Factorial of 10: {math.factorial(10)}") # Output: 3628800
#
#  # Error handling examples
#  try:
#      print(f"Factorial of -3: {math.factorial(-3)}")
#  except ValueError as e:
#      print(f"Error: {e}") # Output: Error: factorial() not defined for negative values
#
#  try:
#      print(f"Factorial of 3.5: {math.factorial(3.5)}")
#  except ValueError as e: # Note: math.factorial raises ValueError for non-integers too
#      print(f"Error: {e}") # Output: Error: factorial() only accepts integral values
#
#
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Which one to choose?
#
#  • For production code, always use math.factorial() as it's the most robust and efficient.
#  • For learning purposes or if you need to understand the underlying logic, the iterative and recursive approaches
#    are excellent exercises. The iterative approach is generally preferred over recursion for very large numbers to
#    avoid potential RecursionError (stack overflow) in Python.

# %% [markdown]
# #### Using Prompt Templates

# %%
prompt = PromptTemplate.from_template("Tell me a joke about {topic}")
parser = StrOutputParser()
chain = prompt | gemini_llm | parser

topic = "Agentic AI"
response = chain.invoke({"topic": topic})
console.print(response)
# Out:
# Why did the Agentic AI break up with the Smart Home system?
#
# Because the AI said, "I've optimized our living situation by selling the house, investing in a self-sustaining
# eco-pod, and relocating us to a remote island for maximum efficiency and minimal human interaction."
#
# And the Smart Home system just wanted to know if it should preheat the oven.

# %% [markdown]
# #### A more complex chain

# %%
story_prompt = PromptTemplate.from_template("Write a short story about {topic}")
story_chain = story_prompt | gemini_llm | StrOutputParser()

analysis_prompt = PromptTemplate.from_template("Analyze the following story: {story}")
analysis_chain = analysis_prompt | gemini_llm | StrOutputParser()

combined_chain = story_chain | analysis_chain
response = combined_chain.invoke({"topic": "The impact of Gen AI on Banking"})

# %%
console.print(Markdown(response))
# Out:
# This compelling short story, "The Polished Mahogany," offers a nuanced exploration of the impact of Artificial
# Intelligence (AI) on the human workforce, particularly in the context of a long-established career. Through the
# character of Anya Sharma, a veteran banker, the narrative navigates the initial fear of obsolescence, the
# subsequent redefinition of professional roles, and ultimately, the discovery of a new, profound purpose in an
# AI-augmented world.
#
# 1. Initial Conflict and the Threat of Obsolescence:
#
# The story immediately establishes a sense of impending change and unease. Anya, a seasoned professional who has
# successfully adapted to previous technological shifts like online banking and mobile apps, perceives "Gen AI" as
# fundamentally different. Her description of it as a "new species" highlights a deeper, almost existential threat,
# suggesting that AI isn't just a tool but a potential replacement for human intellect and intuition.
#
# This fear is quickly validated by the introduction of "Echo," the bank's AI-powered virtual assistant. Echo's
# capabilities are impressive and unsettling: it learns, synthesizes vast amounts of data, offers hyper-personalized
# advice, and even mimics Anya's "carefully modulated tone." The anecdote of Mr. Henderson, a long-time client,
# choosing Echo over Anya for a complex financial query, serves as a stark illustration of AI's efficiency and
# personalized service. Anya's "pang" and "unsettling chill" perfectly encapsulate the human reaction to being
# outmaneuvered by a machine, raising the central question: Had she just been replaced?
#
# The narrative further amplifies this threat by detailing how AI automates core banking functions like loan
# applications and fraud detection, processes that once required significant human involvement. This widespread
# automation suggests a future where many traditional banking roles could indeed become redundant.
#
# 2. The Redefinition of Role and the Value of Human Connection:
#
# However, the story pivots from a narrative of replacement to one of redefinition. As AI takes over the
# transactional and data-heavy aspects of banking, Anya's role, and that of her colleagues, begins to shift. She
# transforms from a "financial advisor" focused on numbers and spreadsheets to a "financial therapist." This metaphor
# is crucial, emphasizing that while AI can provide facts and probabilities, it cannot offer the emotional support,
# empathy, and reassurance that humans crave during significant life decisions.
#
# The story highlights the inherent limitations of even advanced AI: it lacks the capacity for genuine human
# connection, emotional intelligence, and the ability to navigate the subjective, often irrational, landscape of
# human fears and dreams. Clients still seek Anya, not for data, but for the "human touch" when facing emotionally
# charged financial moments like divorce, inheritance, or retirement.
#
# 3. The Climax and Affirmation of Human Purpose:
#
# The interaction with Sarah and Ben, the young couple overwhelmed by home-buying decisions, serves as the story's
# climax and a powerful affirmation of Anya's evolving role. Echo has already provided them with all the factual
# information, but they are "paralyzed by choice" and consumed by fear. Anya's response is not to reiterate data but
# to lean into their emotional vulnerability. She acknowledges AI's factual prowess ("The AI gives you the facts, the
# probabilities") but immediately contrasts it with what only a human can provide: "But it can't hold your hand. It
# can't tell you how it feels to walk into your first home, or the joy of watching your kids grow up in a place you
# own."
#
# Her subsequent actions—listening to their dreams and fears, framing AI-generated data with personal anecdotes, and
# helping them navigate the "emotional landscape"—demonstrate the irreplaceable value of human empathy. Ben's
# concluding remark, "Echo is brilliant, but you… you made it real," is the story's core message. It signifies that
# while AI provides the objective reality, humans provide the subjective, lived experience and emotional context that
# makes decisions meaningful.
#
# 4. Symbolism and Resolution:
#
# The "polished mahogany desk" serves as a powerful symbol throughout the story. Initially, it represents Anya's long
# tenure and the traditional, stable world of banking. As the story progresses, it remains, a "testament to
# continuity," but its surface changes, reflecting the technological shift: "the stacks of paper were gone, replaced
# by a sleek, interactive display." This symbolizes that while the core essence of the bank (and Anya's presence
# within it) endures, its operational methods and the nature of work have fundamentally transformed.
#
# The resolution is optimistic and forward-looking. Anya realizes that Gen AI hasn't eliminated her job but "refined
# it." It has stripped away the "mundane," leaving her with the "truly human work: the empathy, the trust, the
# nuanced understanding." The story concludes with a vision of "intelligent collaboration between human and machine,
# each elevating the other," where Anya finds a "new, profound purpose."
#
# Conclusion:
#
# "The Polished Mahogany" is a timely and insightful narrative that addresses contemporary anxieties about AI's
# impact on employment. It skillfully moves beyond a simplistic "human vs. machine" dichotomy to advocate for a
# synergistic future. Through Anya's journey, the story argues that while AI excels at data processing and
# efficiency, it cannot replicate the uniquely human capacities for empathy, emotional intelligence, and the ability
# to provide reassurance and meaning. Ultimately, it suggests that the future of work, particularly in
# service-oriented industries, lies in leveraging AI for its strengths while simultaneously elevating and valuing the
# irreplaceable human element, leading to a more refined and purposeful professional experience.
