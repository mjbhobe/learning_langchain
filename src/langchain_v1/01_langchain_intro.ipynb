# %% [markdown]
# ### Langchain Version 1.0

# %%
import os
from dotenv import load_dotenv

# load all API keys from local .env file
load_dotenv(override=True)
# Out:
# True

# %%
# create a basic agent
from langchain.agents import create_agent

# agent = create_agent(
#     model="gemini-2.0-flash-1024",
#     tools=[],
#     verbose=True,
# )

# agent.run("What is the capital of France?")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # create a basic agent
# ----> 2 from langchain.agents import create_agent
#       4 # agent = create_agent(
#       5 #     model="gemini-2.0-flash-1024",
#       6 #     tools=[],
#    (...)      9
#      10 # agent.run("What is the capital of France?")
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (C:\Users\BHOBEMRMANISHJAGDISH\Dev\code\git_projects\learning_langchain\.venv\Lib\site-packages\langchain\agents\__init__.py)
